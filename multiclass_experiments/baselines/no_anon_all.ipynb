# %% [markdown]
# ## Start up

# %%
import pandas as pd
import seaborn as sns
from enum import Enum     # for enum34, or the stdlib version
from pycaret.classification import *
from anonymizeip import anonymize_ip

class AnonTypes(Enum):
    BM = 0 # black marker 
    BI = 1 # bilateral classification
    NO = 2 # no anonymization
    
sample = 0
binary = 0

# anonymization flag
tlp_anonymization = AnonTypes.NO
ip_proto_anonymization = AnonTypes.NO
pkt_counter_anonymization = AnonTypes.NO
oct_counter_anonymization = AnonTypes.NO

# %%
from typing import List

def optimize_floats(df: pd.DataFrame) -> pd.DataFrame:
    floats = df.select_dtypes(include=['float64']).columns.tolist()
    df[floats] = df[floats].apply(pd.to_numeric, downcast='float')
    return df


def optimize_ints(df: pd.DataFrame) -> pd.DataFrame:
    ints = df.select_dtypes(include=['int64']).columns.tolist()
    df[ints] = df[ints].apply(pd.to_numeric, downcast='integer')
    return df


def optimize_objects(df: pd.DataFrame, datetime_features: List[str]) -> pd.DataFrame:
    for col in df.select_dtypes(include=['object']):
        if col not in datetime_features:
            if not (type(df[col][0])==list):
                num_unique_values = len(df[col].unique())
                num_total_values = len(df[col])
                if float(num_unique_values) / num_total_values < 0.5:
                    df[col] = df[col].astype('category')
        else:
            df[col] = pd.to_datetime(df[col])
    return df



def optimize(df: pd.DataFrame, datetime_features: List[str] = []):
    return optimize_floats(optimize_ints(optimize_objects(df, datetime_features)))

# %%
df = pd.read_csv("../../NF-ToN-IoT.csv")

# %% [markdown]
# ## Checks

# %% [markdown]
# ### =================================================================

# %%
# Remove non-ipfix standardized features
# See: https://www.ntop.org/guides/nprobe/cli_options.html#netflow-v9-ipfix-format-t
# Thesis: Refer to table 2 for feature names and descriptions

df_ipfix = df[['L4_SRC_PORT', 'L4_DST_PORT', 'PROTOCOL', 'IN_BYTES', 'OUT_BYTES', 'IN_PKTS', 'OUT_PKTS', 'TCP_FLAGS', 'FLOW_DURATION_MILLISECONDS', 'Label', 'Attack']]
#df_ipfix['IPV4_SRC_ADDR'] = df_ipfix['IPV4_SRC_ADDR'].astype('category')
#df_ipfix['IPV4_DST_ADDR'] = df_ipfix['IPV4_DST_ADDR'].astype('category')

df_ipfix = optimize(df_ipfix, [])
df_ipfix.memory_usage()
# Out:
# Index                             128
# L4_SRC_PORT                   5517096
# L4_DST_PORT                   5517096
# PROTOCOL                      1379274
# IN_BYTES                      5517096
# OUT_BYTES                     5517096
# IN_PKTS                       5517096
# OUT_PKTS                      5517096
# TCP_FLAGS                     2758548
# FLOW_DURATION_MILLISECONDS    5517096
# Label                         1379274
# Attack                        1379654
# dtype: int64

# %%
if(binary):
    df_ = df_ipfix.drop("Attack", axis=1)
else:
    df_ = df_ipfix.drop("Label", axis=1)

# Sample data
if(sample):
    df_ = df_.sample(n=1000000)

# %% [markdown]
# ## Feature Anonymization Functions

# %%
def anon_tlp(anon_type, df):
    if(anon_type == AnonTypes.BI): # based on - https://datatracker.ietf.org/doc/html/draft-ietf-ipfix-anon#section-4.5.1
        df['L4_SRC_PORT'] = [0 if int(x) <= 1023 else 1 for x in df['L4_SRC_PORT']]
        df['L4_DST_PORT'] = [0 if int(x) <= 1023 else 1 for x in df['L4_DST_PORT']]
    elif(anon_type == AnonTypes.BM):
        df['L4_SRC_PORT'] = 0
        df['L4_DST_PORT'] = 0
 
    return df
    
def anon_pkt_counters(anon_type, df): 
    if(anon_type == AnonTypes.BI): # based on - https://datatracker.ietf.org/doc/html/draft-ietf-ipfix-anon#section-4.4.2
        df['IN_PKTS'] = [0 if int(x) <= 2 else 1 for x in df['IN_PKTS']]
        df['OUT_PKTS'] = [0 if int(x) <= 2 else 1 for x in df['OUT_PKTS']]
    elif(anon_type == AnonTypes.BM): 
        df['IN_PKTS'] = 0
        df['OUT_PKTS'] = 0
    
    return df

def anon_octet_counters(anon_type, df): 
    mean_bytes_in = round(df_['IN_BYTES'].mean()) 
    mean_bytes_out= round(df_['OUT_BYTES'].mean()) 

    if(anon_type == AnonTypes.BI): # based on - https://datatracker.ietf.org/doc/html/draft-ietf-ipfix-anon#section-4.4.2
        df['IN_BYTES'] = [0 if int(x) <= mean_bytes_in else 1 for x in df['IN_BYTES']]
        df['OUT_BYTES'] = [0 if int(x) <= mean_bytes_out else 1 for x in df['OUT_BYTES']]
    elif(anon_type == AnonTypes.BM): 
        df['IN_BYTES'] = 0
        df['OUT_BYTES'] = 0
    
    return df

def anon_ip_proto(anon_type, df):
    grouped_protocols = [1, 6, 17] # 1, 6, and 17 for ICMP, UDP, and TCP 

    if(anon_type == AnonTypes.BI): # based on - https://datatracker.ietf.org/doc/html/draft-ietf-ipfix-anon#section-4.5.1
        df['PROTOCOL'] = [0 if int(x) in grouped_protocols else 1 for x in df['PROTOCOL']] 
    elif(anon_type == AnonTypes.BM): 
        df['PROTOCOL'] = 0
        
    return df

# %% [markdown]
# ### Anonymization iterations

# %%
#print(df_['L4_SRC_PORT'].value_counts())
df_ = anon_tlp(tlp_anonymization, df_)
df_ = anon_pkt_counters(pkt_counter_anonymization, df_)
df_ = anon_octet_counters(oct_counter_anonymization, df_)
df_ = anon_ip_proto(ip_proto_anonymization, df_)

df_.head()
# Out:
#    L4_SRC_PORT  L4_DST_PORT  PROTOCOL  IN_BYTES  OUT_BYTES  IN_PKTS  OUT_PKTS  \
# 0        63318          443         6       181        165        2         1
# 1        57442        15600        17        63          0        1         0
# 2        57452        15600        17        63          0        1         0
# 3          138          138        17       472          0        2         0
# 4        51989        15600        17        63          0        1         0
#
#    TCP_FLAGS  FLOW_DURATION_MILLISECONDS  Attack
# 0         24                         327  Benign
# 1          0                           0  Benign
# 2          0                           0  Benign
# 3          0                           0  Benign
# 4          0                           0  Benign

# %% [markdown]
# ### =================================================================

# %% [markdown]
# ## Setup

# %%
#df_['ICMP_TYPE'] = df_['ICMP_TYPE'].astype(str)
#df_['ICMP_IPV4_TYPE'] = df_['ICMP_IPV4_TYPE'].astype(str)
categorical = ['L4_SRC_PORT', 'L4_DST_PORT', 'PROTOCOL', 'TCP_FLAGS']

for f in categorical:
    df_[f] = df_[f].astype('str')

#df_ = df_[['TCP_FLAGS', 'FLOW_DURATION_MILLISECONDS', 'Label']]

if(binary):
    session_binary = setup(df_, target = 'Label', experiment_name='binary', categorical_features = categorical, normalize=True, fix_imbalance=True)
else:
    session_multi = setup(df_, target = 'Attack', experiment_name='multiclass', categorical_features = categorical, normalize=True, fix_imbalance=True)
# Out:
# <style type="text/css">
# #T_20a55_row10_col1, #T_20a55_row16_col1, #T_20a55_row18_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_20a55">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20a55_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_20a55_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20a55_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20a55_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_20a55_row0_col1" class="data row0 col1" >1437</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_20a55_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_20a55_row1_col1" class="data row1 col1" >Attack</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_20a55_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_20a55_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_20a55_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_20a55_row3_col1" class="data row3 col1" >Benign: 0, backdoor: 1, ddos: 2, dos: 3, injection: 4, mitm: 5, password: 6, ransomware: 7, scanning: 8, xss: 9</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_20a55_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_20a55_row4_col1" class="data row4 col1" >(1379274, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_20a55_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_20a55_row5_col1" class="data row5 col1" >(3693553, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_20a55_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_20a55_row6_col1" class="data row6 col1" >(3279770, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_20a55_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_20a55_row7_col1" class="data row7 col1" >(413783, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_20a55_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_20a55_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_20a55_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_20a55_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_20a55_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_20a55_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_20a55_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_20a55_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_20a55_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_20a55_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_20a55_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_20a55_row13_col1" class="data row13 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_20a55_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_20a55_row14_col1" class="data row14 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_20a55_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_20a55_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_20a55_row16_col0" class="data row16 col0" >Fix imbalance</td>
#       <td id="T_20a55_row16_col1" class="data row16 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_20a55_row17_col0" class="data row17 col0" >Fix imbalance method</td>
#       <td id="T_20a55_row17_col1" class="data row17 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_20a55_row18_col0" class="data row18 col0" >Normalize</td>
#       <td id="T_20a55_row18_col1" class="data row18 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_20a55_row19_col0" class="data row19 col0" >Normalize method</td>
#       <td id="T_20a55_row19_col1" class="data row19 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_20a55_row20_col0" class="data row20 col0" >Fold Generator</td>
#       <td id="T_20a55_row20_col1" class="data row20 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_20a55_row21_col0" class="data row21 col0" >Fold Number</td>
#       <td id="T_20a55_row21_col1" class="data row21 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_20a55_row22_col0" class="data row22 col0" >CPU Jobs</td>
#       <td id="T_20a55_row22_col1" class="data row22 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_20a55_row23_col0" class="data row23 col0" >Use GPU</td>
#       <td id="T_20a55_row23_col1" class="data row23 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_20a55_row24_col0" class="data row24 col0" >Log Experiment</td>
#       <td id="T_20a55_row24_col1" class="data row24 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_20a55_row25_col0" class="data row25 col0" >Experiment Name</td>
#       <td id="T_20a55_row25_col1" class="data row25 col1" >multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_20a55_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_20a55_row26_col0" class="data row26 col0" >USI</td>
#       <td id="T_20a55_row26_col1" class="data row26 col1" >9e96</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models(sort = 'F1')
# Out:
# <style type="text/css">
# #T_92f72 th {
#   text-align: left;
# }
# #T_92f72_row0_col0, #T_92f72_row0_col2, #T_92f72_row0_col4, #T_92f72_row1_col0, #T_92f72_row1_col1, #T_92f72_row1_col2, #T_92f72_row1_col3, #T_92f72_row1_col4, #T_92f72_row1_col5, #T_92f72_row1_col6, #T_92f72_row1_col7, #T_92f72_row2_col0, #T_92f72_row2_col1, #T_92f72_row2_col3, #T_92f72_row2_col5, #T_92f72_row2_col6, #T_92f72_row2_col7, #T_92f72_row3_col0, #T_92f72_row3_col1, #T_92f72_row3_col2, #T_92f72_row3_col3, #T_92f72_row3_col4, #T_92f72_row3_col5, #T_92f72_row3_col6, #T_92f72_row3_col7, #T_92f72_row4_col0, #T_92f72_row4_col1, #T_92f72_row4_col2, #T_92f72_row4_col3, #T_92f72_row4_col4, #T_92f72_row4_col5, #T_92f72_row4_col6, #T_92f72_row4_col7, #T_92f72_row5_col0, #T_92f72_row5_col1, #T_92f72_row5_col2, #T_92f72_row5_col3, #T_92f72_row5_col4, #T_92f72_row5_col5, #T_92f72_row5_col6, #T_92f72_row5_col7, #T_92f72_row6_col0, #T_92f72_row6_col1, #T_92f72_row6_col2, #T_92f72_row6_col3, #T_92f72_row6_col4, #T_92f72_row6_col5, #T_92f72_row6_col6, #T_92f72_row6_col7, #T_92f72_row7_col0, #T_92f72_row7_col1, #T_92f72_row7_col2, #T_92f72_row7_col3, #T_92f72_row7_col4, #T_92f72_row7_col5, #T_92f72_row7_col6, #T_92f72_row7_col7, #T_92f72_row8_col0, #T_92f72_row8_col1, #T_92f72_row8_col2, #T_92f72_row8_col3, #T_92f72_row8_col4, #T_92f72_row8_col5, #T_92f72_row8_col6, #T_92f72_row8_col7, #T_92f72_row9_col0, #T_92f72_row9_col1, #T_92f72_row9_col2, #T_92f72_row9_col3, #T_92f72_row9_col4, #T_92f72_row9_col5, #T_92f72_row9_col6, #T_92f72_row9_col7, #T_92f72_row10_col0, #T_92f72_row10_col1, #T_92f72_row10_col2, #T_92f72_row10_col3, #T_92f72_row10_col4, #T_92f72_row10_col5, #T_92f72_row10_col6, #T_92f72_row10_col7, #T_92f72_row11_col0, #T_92f72_row11_col1, #T_92f72_row11_col2, #T_92f72_row11_col3, #T_92f72_row11_col4, #T_92f72_row11_col5, #T_92f72_row11_col6, #T_92f72_row11_col7, #T_92f72_row12_col0, #T_92f72_row12_col1, #T_92f72_row12_col2, #T_92f72_row12_col3, #T_92f72_row12_col4, #T_92f72_row12_col5, #T_92f72_row12_col6, #T_92f72_row12_col7, #T_92f72_row13_col0, #T_92f72_row13_col1, #T_92f72_row13_col2, #T_92f72_row13_col3, #T_92f72_row13_col4, #T_92f72_row13_col5, #T_92f72_row13_col6, #T_92f72_row13_col7 {
#   text-align: left;
# }
# #T_92f72_row0_col1, #T_92f72_row0_col3, #T_92f72_row0_col5, #T_92f72_row0_col6, #T_92f72_row0_col7, #T_92f72_row2_col2, #T_92f72_row2_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_92f72_row0_col8, #T_92f72_row1_col8, #T_92f72_row2_col8, #T_92f72_row3_col8, #T_92f72_row4_col8, #T_92f72_row5_col8, #T_92f72_row6_col8, #T_92f72_row7_col8, #T_92f72_row8_col8, #T_92f72_row9_col8, #T_92f72_row10_col8, #T_92f72_row11_col8, #T_92f72_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_92f72_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_92f72">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92f72_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_92f72_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_92f72_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_92f72_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_92f72_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_92f72_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_92f72_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_92f72_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_92f72_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92f72_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_92f72_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_92f72_row0_col1" class="data row0 col1" >0.6137</td>
#       <td id="T_92f72_row0_col2" class="data row0 col2" >0.8410</td>
#       <td id="T_92f72_row0_col3" class="data row0 col3" >0.6137</td>
#       <td id="T_92f72_row0_col4" class="data row0 col4" >0.6599</td>
#       <td id="T_92f72_row0_col5" class="data row0 col5" >0.6315</td>
#       <td id="T_92f72_row0_col6" class="data row0 col6" >0.5148</td>
#       <td id="T_92f72_row0_col7" class="data row0 col7" >0.5179</td>
#       <td id="T_92f72_row0_col8" class="data row0 col8" >29.9520</td>
#     </tr>
#     <tr>
#       <th id="T_92f72_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_92f72_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_92f72_row1_col1" class="data row1 col1" >0.6067</td>
#       <td id="T_92f72_row1_col2" class="data row1 col2" >0.8164</td>
#       <td id="T_92f72_row1_col3" class="data row1 col3" >0.6067</td>
#       <td id="T_92f72_row1_col4" class="data row1 col4" >0.5386</td>
#       <td id="T_92f72_row1_col5" class="data row1 col5" >0.5509</td>
#       <td id="T_92f72_row1_col6" class="data row1 col6" >0.4575</td>
#       <td id="T_92f72_row1_col7" class="data row1 col7" >0.4853</td>
#       <td id="T_92f72_row1_col8" class="data row1 col8" >55.2990</td>
#     </tr>
#     <tr>
#       <th id="T_92f72_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_92f72_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_92f72_row2_col1" class="data row2 col1" >0.4702</td>
#       <td id="T_92f72_row2_col2" class="data row2 col2" >0.8774</td>
#       <td id="T_92f72_row2_col3" class="data row2 col3" >0.4702</td>
#       <td id="T_92f72_row2_col4" class="data row2 col4" >0.7531</td>
#       <td id="T_92f72_row2_col5" class="data row2 col5" >0.5161</td>
#       <td id="T_92f72_row2_col6" class="data row2 col6" >0.3913</td>
#       <td id="T_92f72_row2_col7" class="data row2 col7" >0.4254</td>
#       <td id="T_92f72_row2_col8" class="data row2 col8" >929.1230</td>
#     </tr>
#     <tr>
#       <th id="T_92f72_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_92f72_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_92f72_row3_col1" class="data row3 col1" >0.5398</td>
#       <td id="T_92f72_row3_col2" class="data row3 col2" >0.7880</td>
#       <td id="T_92f72_row3_col3" class="data row3 col3" >0.5398</td>
#       <td id="T_92f72_row3_col4" class="data row3 col4" >0.5326</td>
#       <td id="T_92f72_row3_col5" class="data row3 col5" >0.5156</td>
#       <td id="T_92f72_row3_col6" class="data row3 col6" >0.3931</td>
#       <td id="T_92f72_row3_col7" class="data row3 col7" >0.4129</td>
#       <td id="T_92f72_row3_col8" class="data row3 col8" >63.6500</td>
#     </tr>
#     <tr>
#       <th id="T_92f72_level0_row4" class="row_heading level0 row4" >svm</th>
#       <td id="T_92f72_row4_col0" class="data row4 col0" >SVM - Linear Kernel</td>
#       <td id="T_92f72_row4_col1" class="data row4 col1" >0.4452</td>
#       <td id="T_92f72_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_92f72_row4_col3" class="data row4 col3" >0.4452</td>
#       <td id="T_92f72_row4_col4" class="data row4 col4" >0.7257</td>
#       <td id="T_92f72_row4_col5" class="data row4 col5" >0.4753</td>
#       <td id="T_92f72_row4_col6" class="data row4 col6" >0.3602</td>
#       <td id="T_92f72_row4_col7" class="data row4 col7" >0.4011</td>
#       <td id="T_92f72_row4_col8" class="data row4 col8" >9.1230</td>
#     </tr>
#     <tr>
#       <th id="T_92f72_level0_row5" class="row_heading level0 row5" >gbc</th>
#       <td id="T_92f72_row5_col0" class="data row5 col0" >Gradient Boosting Classifier</td>
#       <td id="T_92f72_row5_col1" class="data row5 col1" >0.4032</td>
#       <td id="T_92f72_row5_col2" class="data row5 col2" >0.7423</td>
#       <td id="T_92f72_row5_col3" class="data row5 col3" >0.4032</td>
#       <td id="T_92f72_row5_col4" class="data row5 col4" >0.6364</td>
#       <td id="T_92f72_row5_col5" class="data row5 col5" >0.4303</td>
#       <td id="T_92f72_row5_col6" class="data row5 col6" >0.3124</td>
#       <td id="T_92f72_row5_col7" class="data row5 col7" >0.3460</td>
#       <td id="T_
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')
